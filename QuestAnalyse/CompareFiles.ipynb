# %%
# %matplotlib inline
from ComparedDataFile import ComparedDataFile

# %%
CompFile=ComparedDataFile(r'.\excDoc\ShortSample.xlsx',r'.\excDoc\ShortSample2.xlsx')
# Out:
# loading first file...
# calculating results...
# converting data...
# first file complete
# loading second file...
# calculating results...
# converting data...
# Second file complete
# size file 1: 21
# size file 2: 21

# %%
CompFile.cognitive_load('tab')
#tester lesquel sont les levels de significance
#vérifier si ztest_Score ets l'equivalent de t value
# Out:
# level of significance: 0.05
# type of test: t-test
# independant
#                 categories    file 1    file 2   p-value Significant diff  \
# 0       Mentally demanding  4.142857  3.761905  0.543561               no
# 1      Physicaly demanding  4.190476  3.761905  0.487447               no
# 2   Hurried or rushed pace  3.238095  4.428571  0.069388               no
# 3               difficulty  3.428571  3.904762  0.487042               no
#
# 0                  success  4.142857  4.619048  0.474798               no
# 1  overall easiness to use  3.904762  3.190476  0.269698               no
#
#   Best File
# 0         /
# 1         /
# 2         /
# 3         /
#
# 0         /
# 1         /

# %%
CompFile.cognitive_load_Qual_Analysis()

# %%
CompFile.Knowledge_Gain('tab')
# Out:
# level of significance: 0.05
# type of test: t-test
# problem= i'm only testing if the difference is existent + success and overall different
# independant
#        categories    file 1    file 2   p-value Significant diff Best File
# 0         Quality  4.285714  3.285714  0.165597               no         /
# 1  Interpretation  4.000000  4.333333  0.583422               no         /
# 2       Critiques  4.428571  3.714286  0.256102               no         /

# %%
CompFile.Knowledge_Gain_Qual_Analysis()

# %%
CompFile.Software_Usability('tab')
# Out:
# level of significance: 0.05
# type of test: t-test
# problem= i'm only testing if the difference is existent + success and overall different
# independant
#                                                   categories    file 1  \
# System
# 0                                          Simplicity to use  4.380952
# 1                             helped effectivness of my work  3.571429
# 2                                     helped pace of my work   3.52381
# 3                                         confortable system  4.190476
# 4                                easy recovery after mistake  4.095238
# 5                                       overall satisfaction  3.809524
# Information
# 0                                                      clear  4.095238
# 1                                               easy to find  4.761905
# 2                                                  effective  3.142857
# 3                                                  organized  4.238095
# Interface
# ...

# %%
CompFile.Software_Usability_Qual()

# %%
CompFile.Searching_Learning('tab')
# Out:
# level of significance: 0.05
# type of test: t-test
# problem= i'm only testing if the difference is existent + success and overall different
# independant
#                                                        categories    file 1  \
# Search formulation
# 0                                            Background knowledge  3.809524
# 1                                               Interest in topic  3.952381
# 2                                          Anticipated difficulty       4.0
# Content Selection
# 0                                               Actual difficulty  3.047619
# 1                                       text presentation quality  3.809524
# 2                           average number of doc view per search  3.333333
# 3                               the usefullness of search results  4.095238
# 4                                                  text relevance  4.619048
# Interaction with content
# ...

# %%
CompFile.Searching_Learning_Qual()

# %%
CompFile.User_Experience_Qual_Analysis('pdf')
# Out:
# loading pdf...
# pdf downloaded !

# %% [markdown]
# you have to input a parameter for the format of the display that can be either 'graph' that will display the data in graphic format, 'tab' that will display the information in a tab or 'full' that will display the inforation in the 2 formats. You can also add the confidence level you wish to calculate. Entering 0.05 will assure you a 95 confidence level (default confidence level)
#
#
# To-do list avant le 16:
#
# gerer problème excel (gérer ajd si possible)
#
# faire documentation (plus tard)
# checker pk z test n'a pas besoin d'un alpha (hum)
#
# gérer problème titre des graphiques(gérer jeudi)
# pdf de comments flou (gérer jeudi)

# %%
CompFile.Software_Usability_Coments('pdf')
# Out:
# <style type="text/css">
# #T_48bcf_ thead {
#   background-color: gray;
# }
# #T_48bcf_ .row21 {
#   background-color: gray;
# }
# </style>
# <table id="T_48bcf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >System: If it was difficult to recover from any mistake, please comment on the problems.</th>
#       <th class="col_heading level0 col1" >Information:if any information was not clear, what difficulties did you face?</th>
#       <th class="col_heading level0 col2" >What functions and capabilities would you like to see in this system?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48bcf_level0_row0" class="row_heading level0 row0" >Ur_1</th>
#       <td id="T_48bcf_row0_col0" class="data row0 col0" >The system itself suggest what you meant by understanding your questions.</td>
# ...
